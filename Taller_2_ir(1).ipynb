# %%
Julián Esteban Pacheco 20202015125
Mariana obando Gutierrez 20192005009
Juan Pablo Dominguez Moreno 20221005039

# %%
# Datos de entrada
data_in = [341730, 8555, 4278, 500, 500, 501, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 500, 500, 501, 500, 500, 501, 1604, 500, 500, 501, 1604, 500, 1604, 501, 500, 500, 1604, 501, 1603, 501, 1604, 500, 501, 500, 1604, 500, 501, 500, 500, 501, 1604, 500, 127092, 8555, 4277, 501, 500, 500, 501, 500, 500, 501, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 1604, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 500, 501, 500, 501, 500, 500, 1604, 501, 500, 500, 1604, 501, 1604, 500, 500, 501, 1604, 500, 1604, 501, 1603, 501, 500, 501, 1603, 501, 500, 501, 500, 500, 1604, 501, 32034, 8555, 4278, 500, 500, 501, 500, 501, 500, 500, 501, 500, 500, 501, 500, 501, 500, 500, 501, 500, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 1604, 501, 500, 500, 501, 500, 500, 501, 1604, 500, 500, 501, 1604, 500, 1604, 501, 500, 500, 1604, 501, 1603, 501, 1604, 500, 501, 500, 1604, 500, 501, 500, 500, 501, 1604, 500, 63721, 8555, 4277, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 500, 501, 500, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 500, 501, 500, 500, 501, 500, 1604, 501, 500, 500, 1604, 501, 1603, 501, 500, 501, 1603, 501, 1604, 500, 1604, 501, 500, 500, 1604, 501, 500, 500, 501, 500, 1604, 500, 32035, 8555, 4278, 500, 500, 501, 500, 500, 501, 500, 500, 501, 500, 501, 500, 500, 501, 500, 500, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 501, 500, 500, 501, 500, 501, 1603, 501, 500, 501, 1603, 501, 1604, 500, 501, 500, 1604, 500, 1604, 501, 1604, 500, 500, 501, 1604, 500, 500, 501, 500, 501, 1604, 500, 63720, 8555, 4278, 500, 501, 500, 500, 501, 500, 501, 500, 500, 500, 501, 500, 501, 500, 500, 501, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 1603, 501, 500, 501, 500, 500, 501, 500, 1604, 500, 501, 500, 1604, 500, 1604, 501, 500, 501, 1603, 501, 1604, 500, 1604, 501, 500, 500, 1604, 501, 500, 500, 501, 500, 1604, 500, 32035, 8555, 4277, 501, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 500, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 501, 500, 500, 501, 500, 501, 1603, 501, 500, 501, 1603, 501, 1604, 500, 500, 501, 1604, 500, 1604, 501, 1604, 500, 500, 501, 1604, 500, 500, 501, 500, 501, 1603, 501, 32034, 8556, 4277, 500, 501, 500, 500, 501, 500, 501, 500, 500, 501, 500, 500, 501, 500, 501, 500, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 1603, 501, 500, 501, 500, 500, 501, 500, 1604, 500, 501, 500, 1604, 500, 1604, 501, 500, 501, 1603, 501, 1604, 500, 1604, 501, 500, 500, 1604, 501, 500, 500, 501, 500, 1604, 500, 32035, 8555, 4277, 501, 500, 501, 500, 500, 501, 500, 500, 501, 500, 501, 500, 500, 501, 500, 500, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 501, 500, 500, 501, 500, 501, 1603, 501, 500, 501, 1603, 501, 1604, 500, 501, 500, 1604, 500, 1604, 501, 1604, 500, 500, 501, 1604, 500, 500, 501, 500, 501, 1603, 501, 32035, 8555, 4277, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 500, 501, 500, 500, 1604, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 1604, 500, 1604, 501, 1604, 500, 500, 501, 500, 501, 500, 500, 1604, 501, 500, 500, 1604, 501, 1604, 500, 500, 501, 1604, 500, 1604, 500, 1604, 501, 500, 500, 1604, 501, 500, 501, 500, 500, 1604, 501]
data_out = []
data_temp = []


for data in data_in:
    if data >= 10000:
        if data_temp:
            data_out.append(data_temp)
        data_temp = []
    data_temp.append(data)


if data_temp:
    data_out.append(data_temp)

dataf=[]
for i, dtout in enumerate(data_out):
    dtout.pop(0)
    dataf.append(dtout)

for sublist in dataf:
    print(sublist)
# Out:
# [8555, 4278, 500, 500, 501, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 500, 500, 501, 500, 500, 501, 1604, 500, 500, 501, 1604, 500, 1604, 501, 500, 500, 1604, 501, 1603, 501, 1604, 500, 501, 500, 1604, 500, 501, 500, 500, 501, 1604, 500]
# [8555, 4277, 501, 500, 500, 501, 500, 500, 501, 500, 501, 500, 500, 501, 500, 500, 501, 500, 500, 1604, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 1604, 501, 1603, 501, 1604, 500, 500, 501, 500, 501, 500, 500, 1604, 501, 500, 500, 1604, 501, 1604, 500, 500, 501, 1604, 500, 1604, 501, 1603, 501, 500, 501, 1603, 501, 500, 501, 500, 500, 1604, 501]
# ...

# %%
for dato in dataf:
    print(len(dato),end=', ')
# Out:
# 67, 67, 67, 67, 67, 67, 67, 67, 67, 67,

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 3]

x_val=list(range(75))
x=[str(i) for i in range(75)]
fig, ax = plt.subplots()
for dato in dataf:
    ax.plot(dato)
plt.xticks(x_val)
plt.show()

# %%
import numpy as np
A=np.array(dataf)
A.shape
# Out:
# (10, 67)

# %%
promedios=A.mean(axis=0)
promedios.shape
# Out:
# (67,)

# %%
maximos=A.max(axis=0)
maximos.shape
# Out:
# (67,)

# %%
minimos=A.min(axis=0)
minimos.shape
# Out:
# (67,)

# %%
desv_est=A.std(axis=0)
desv_est.shape
# Out:
# (67,)

# %%
for i in range(67):
    print(promedios[i],maximos[i],minimos[i],desv_est[i])
# Out:
# 8555.1 8556 8555 0.3
# 4277.4 4278 4277 0.4898979485566356
# 500.5 501 500 0.5
# 500.2 501 500 0.4
# 500.5 501 500 0.5
# 500.3 501 500 0.45825756949558394
# 500.4 501 500 0.4898979485566357
# 500.3 501 500 0.45825756949558405
# 500.5 501 500 0.5
# 500.2 501 500 0.3999999999999999
# 500.4 501 500 0.4898979485566357
# 500.3 501 500 0.45825756949558394
# 500.5 501 500 0.5
# 500.2 501 500 0.39999999999999997
# 500.5 501 500 0.5
# 500.3 501 500 0.45825756949558405
# 500.5 501 500 0.5
# 500.2 501 500 0.39999999999999997
# 500.4 501 500 0.4898979485566357
# 1604.0 1604 1604 0.0
# 500.5 501 500 0.5
# 1603.7 1604 1603 0.45825756949558405
# 500.5 501 500 0.5
# 1603.9 1604 1603 0.3
# 500.5 501 500 0.5
# 1603.9 1604 1603 0.3
# 500.5 501 500 0.5
# 1603.8 1604 1603 0.4
# 500.4 501 500 0.4898979485566357
# 1603.9 1604 1603 0.3
# 500.5 501 500 0.5
# 1603.9 1604 1603 0.3
# 500.5 501 500 0.5
# 1603.8 1604 1603 0.4
# 500.4 501 500 0.4898979485566357
# 500.3 501 500 0.45825756949558405
# ...

# %%
impares=[promedios[i] for i in range(2,67) if i%2==1  ]
print(impares, end='')
# Out:
# [500.2, 500.3, 500.3, 500.2, 500.3, 500.2, 500.3, 500.2, 1604.0, 1603.7, 1603.9, 1603.9, 1603.8, 1603.9, 1603.9, 1603.8, 500.3, 500.2, 500.3, 1603.7, 500.2, 1603.7, 1603.9, 500.2, 1603.7, 1603.8, 1603.9, 500.2, 1603.9, 500.2, 500.3, 1603.8]

# %%
pares=[promedios[i] for i in range(2,67) if i%2==0  ]
print(pares, end='')
# Out:
# [500.5, 500.5, 500.4, 500.5, 500.4, 500.5, 500.5, 500.5, 500.4, 500.5, 500.5, 500.5, 500.5, 500.4, 500.5, 500.5, 500.4, 500.5, 500.5, 500.5, 500.6, 500.5, 500.6, 500.5, 500.6, 500.5, 500.6, 500.5, 500.4, 500.5, 500.5, 500.5, 500.4]

# %%
len(pares),max(pares),min(pares),sum(pares)/len(pares)
# Out:
# (33, 500.6, 500.4, 500.4909090909091)

# %%
len(impares)
# Out:
# 32

# %%
binario=[('1' if impares[i] > 1000 else '0')  for i in range(32) ]
binario=''.join(binario)
binario
# Out:
# '00000000111111110001011011101001'

# %%
cod=[int(binario[i*8 : (i+1)*8],2)  for i in range(4)]
cod
# Out:
# [0, 255, 22, 233]

# %%
[hex(val) for val in cod]
# Out:
# ['0x0', '0xff', '0x16', '0xe9']
